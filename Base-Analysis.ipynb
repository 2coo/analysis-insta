# %%
import pandas as pd
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# # Advertiser

# %%
account = pd.read_csv("Data/ad_account.csv")

# %%
account.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 60 columns):
# id                                        110 non-null int64
# account_status                            110 non-null int64
# name                                      110 non-null object
# owner                                     110 non-null int64
# age                                       110 non-null float64
# agency_client_declaration                 110 non-null object
# amount_spent                              110 non-null int64
# attribution_spec                          110 non-null object
# balance                                   110 non-null int64
# business                                  110 non-null object
# business_city                             3 non-null object
# business_country_code                     110 non-null object
# business_name                             3 non-null object
# business_state                            3 non-null object
# ...

# %%
account.head()
# Out:
#                 id  account_status  \
# 0  101474203315437               1
# 1  103584809830089               1
# 2  105127429601931               1
# 3  107523299420494               1
# 4  142977109919742               1
#
#                                             name            owner       age  \
# 0                              coca_cola_DD_Coca  550011445100868  2834.270
# 1                     Yahoo Japan Corporation_DD  550011445100868  2448.930
# 2          Nikkei Business Publications, Inc._DD  550011445100868  2931.190
# 3                    Nikon Imaging Japan inc._DD  550011445100868  2519.130
# 4  NOMURA SECURITIES CO., LTD.(Koza kaisetsu)_DD  449750032146539   145.007
#
#   agency_client_declaration  amount_spent  \
# 0                      None     162187598
# 1                      None      27992562
# 2                      None     126213772
# 3                      None      41318643
# 4                      None       3814295
#
# ...

# %% [markdown]
# # Campaign

# %%
campaign = pd.read_csv("Data/campaign.csv")

# %%
campaign.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255 entries, 0 to 254
# Data columns (total 28 columns):
# id                             255 non-null int64
# account_id                     255 non-null int64
# budget_rebalance_flag          255 non-null int64
# budget_remaining               255 non-null int64
# buying_type                    255 non-null object
# can_create_brand_lift_study    255 non-null int64
# can_use_spend_cap              255 non-null int64
# configured_status              255 non-null object
# created_time                   255 non-null object
# effective_status               255 non-null object
# name                           255 non-null object
# objective                      255 non-null object
# source_campaign_id             255 non-null int64
# start_time                     255 non-null object
# status                         255 non-null object
# stop_time                      202 non-null object
# ...

# %%
campaign.head()
# Out:
#               id       account_id  budget_rebalance_flag  budget_remaining  \
# 0  6019850536827  590550984380247                      0                 0
# 1  6022512678027  590550984380247                      0                 0
# 2  6062808431110  347882235370392                      0                 0
# 3  6062859532179  710359735732704                      0                 0
# 4  6080109713338  622353771199968                      0                 0
#
#   buying_type  can_create_brand_lift_study  can_use_spend_cap  \
# 0     AUCTION                            0                  1
# 1     AUCTION                            0                  1
# 2     AUCTION                            0                  1
# 3     AUCTION                            0                  1
# 4     AUCTION                            0                  1
#
#   configured_status         created_time effective_status  ... bid_strategy  \
# ...

# %% [markdown]
# # Adset

# %%
adset = pd.read_csv("Data/ad_set.csv")

# %%
adset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 339 entries, 0 to 338
# Data columns (total 65 columns):
# id                                        339 non-null int64
# account_id                                339 non-null int64
# campaign_id                               339 non-null int64
# attribution_spec_event_type               333 non-null object
# attribution_spec_windows_days             333 non-null float64
# bid_amount                                28 non-null float64
# bid_info                                  28 non-null object
# bid_strategy                              267 non-null object
# billing_event                             339 non-null object
# budget_remaining                          339 non-null int64
# configured_status                         339 non-null object
# created_time                              339 non-null object
# daily_budget                              277 non-null float64
# ...

# %%
adset.head()
# Out:
#               id       account_id    campaign_id attribution_spec_event_type  \
# 0  6072103951310  347882235370392  6062808431110               CLICK_THROUGH
# 1  6072104279510  347882235370392  6062808431110               CLICK_THROUGH
# 2  6080317869938  622353771199968  6080109713338               CLICK_THROUGH
# 3  6084538621310  347882235370392  6062808431110               CLICK_THROUGH
# 4  6085386221830  760703960698281  6085385711230               CLICK_THROUGH
#
#    attribution_spec_windows_days  bid_amount            bid_info  \
# 0                           28.0         NaN                 NaN
# 1                           28.0     14000.0  {'ACTIONS': 14000}
# 2                            7.0         NaN                 NaN
# 3                           28.0         NaN                 NaN
# 4                            7.0         NaN                 NaN
#
#                bid_strategy billing_event  budget_remaining  ...  \
# ...

# %% [markdown]
# # Ad

# %%
ad = pd.read_csv("Data/ad.csv")

# %%
ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 24 columns):
# id                        397 non-null int64
# account_id                397 non-null int64
# adlabels                  0 non-null float64
# adset_id                  397 non-null int64
# bid_amount                32 non-null float64
# bid_info                  32 non-null object
# bid_type                  397 non-null object
# campaign_id               397 non-null int64
# configured_status         397 non-null object
# conversion_specs          346 non-null object
# created_time              397 non-null object
# creative_id               397 non-null int64
# effective_status          397 non-null object
# last_updated_by_app_id    397 non-null int64
# name                      397 non-null object
# updated_time              397 non-null object
# recommendations           103 non-null object
# source_ad_id              397 non-null int64
# ...

# %%
ad.head()
# Out:
#               id       account_id  adlabels       adset_id  bid_amount  \
# 0  6072314762110  347882235370392       NaN  6072103951310         NaN
# 1  6077849462110  347882235370392       NaN  6072104279510     14000.0
# 2  6078091903510  347882235370392       NaN  6072104279510     14000.0
# 3  6080317872938  622353771199968       NaN  6080317869938         NaN
# 4  6081744147910  347882235370392       NaN  6072103951310         NaN
#
#              bid_info       bid_type    campaign_id configured_status  \
# 0                 NaN  ABSOLUTE_OCPM  6062808431110            PAUSED
# 1  {'ACTIONS': 14000}  ABSOLUTE_OCPM  6062808431110            PAUSED
# 2  {'ACTIONS': 14000}  ABSOLUTE_OCPM  6062808431110            PAUSED
# 3                 NaN  ABSOLUTE_OCPM  6080109713338            ACTIVE
# 4                 NaN  ABSOLUTE_OCPM  6062808431110            PAUSED
#
#                                     conversion_specs  ...  \
# ...

# %% [markdown]
# # Creative

# %%
creative = pd.read_csv('Data/creative.csv')

# %%
creative.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 399 entries, 0 to 398
# Data columns (total 41 columns):
# id                                 399 non-null int64
# account_id                         399 non-null int64
# ad_id                              399 non-null int64
# actor_id                           399 non-null int64
# adlabels                           0 non-null float64
# applink_treatment                  0 non-null float64
# asset_feed_spec                    61 non-null object
# body                               267 non-null object
# branded_content_sponsor_page_id    0 non-null float64
# call_to_action_type                306 non-null object
# effective_instagram_story_id       336 non-null float64
# effective_object_story_id          399 non-null object
# image_crops                        0 non-null float64
# image_hash                         200 non-null object
# image_url                          200 non-null object
# ...

# %%
creative.head()
# Out:
#               id       account_id          ad_id         actor_id  adlabels  \
# 0  6072690421110  347882235370392  6072314762110  235670193242006       NaN
# 1  6077849495710  347882235370392  6077849462110  235670193242006       NaN
# 2  6078091918510  347882235370392  6078091903510  235670193242006       NaN
# 3  6080365076338  622353771199968  6080317872938  124946600918797       NaN
# 4  6081744226910  347882235370392  6081744147910  235670193242006       NaN
#
#    applink_treatment asset_feed_spec  \
# 0                NaN             NaN
# 1                NaN             NaN
# 2                NaN             NaN
# 3                NaN             NaN
# 4                NaN             NaN
#
#                                                 body  \
# 0                 全身22ヵ所を脱毛し放題！月額6800円（税抜）で手軽に始められる！
# 1                                                NaN
# 2                                                NaN
# 3  話題の新スマホ　好評発売中！\n話題の新スマホが、下取りと家族まとめて割で機種代金が実質¥0...
# ...

# %% [markdown]
# # Video

# %%
video = pd.read_csv('Data/insight.csv')

# %%
video.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 407 entries, 0 to 406
# Data columns (total 63 columns):
# ad_id                                407 non-null int64
# account_currency                     407 non-null object
# account_id                           407 non-null int64
# account_name                         407 non-null object
# ad_name                              407 non-null object
# adset_id                             407 non-null int64
# adset_name                           407 non-null object
# buying_type                          407 non-null object
# campaign_id                          407 non-null int64
# campaign_name                        407 non-null object
# canvas_avg_view_percent              0 non-null float64
# canvas_avg_view_time                 0 non-null float64
# clicks                               407 non-null int64
# cost_per_estimated_ad_recallers      52 non-null float64
# cost_per_inline_link_click           353 non-null float64
# ...

# %%
video.head()
# Out:
#                 id       account_id        creative_id          placement  \
# 0  131200354429138  760703960698281      6100597354030  object_story_spec
# 1  131698267659563  921453527956656  23842742462880283  object_story_spec
# 2  143442503152634  728188133949864      6109339096326  object_story_spec
# 3  148709052678268  866402673461742  23842984094160367  object_story_spec
# 4  148727972676376  866402673461742  23842984095170367  object_story_spec
#
#           created_time description  \
# 0  2018-06-07 06:50:47         NaN
# 1  2018-03-05 13:04:29         NaN
# 2  2018-03-22 04:21:22         NaN
# 3  2018-07-19 03:58:42         NaN
# 4  2018-07-19 04:43:52         NaN
#
#                                           embed_html  \
# 0  <iframe src="https://www.facebook.com/plugins/...
# 1  <iframe src="https://www.facebook.com/plugins/...
# 2  <iframe src="https://www.facebook.com/plugins/...
# 3  <iframe src="https://www.facebook.com/plugins/...
# ...

# %%
video = pd.read_csv('Data/video_s3.csv')

# %%
video.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
# video_id           200 non-null int64
# name               200 non-null object
# url                200 non-null object
# aspect_ratio       0 non-null float64
# downloaded_time    200 non-null object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 7.9+ KB

# %%
video.head()
# Out:
#           video_id                       name  \
# 0  131200354429138  131200354429138_video.mp4
# 1  131698267659563  131698267659563_video.mp4
# 2  143442503152634  143442503152634_video.mp4
# 3  148709052678268  148709052678268_video.mp4
# 4  148727972676376  148727972676376_video.mp4
#
#                                             url  aspect_ratio  \
# 0  fb/creatives/video/131200354429138_video.mp4           NaN
# 1  fb/creatives/video/131698267659563_video.mp4           NaN
# 2  fb/creatives/video/143442503152634_video.mp4           NaN
# 3   fb/creative/video/148709052678268_video.mp4           NaN
# 4   fb/creative/video/148727972676376_video.mp4           NaN
#
#        downloaded_time
# 0  2019-11-20 19:42:55
# 1  2019-11-19 23:09:48
# 2  2019-11-20 15:34:46
# 3  2019-11-21 08:43:36
# 4  2019-11-21 08:43:38

# %%
video = pd.read_csv('Data/image_s3.csv')

# %%
video.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
# creative_id        200 non-null int64
# name               200 non-null object
# url                200 non-null object
# downloaded_time    200 non-null object
# dtypes: int64(1), object(3)
# memory usage: 6.4+ KB
